# %%
import pandas as pd 
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("C://Users//USER11//Desktop//DataScience//23Sept_Assignments//Hackathon_Working_Data.csv")
df
# Out:
#       MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0        M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1        M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2        M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3        M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4        M1        N1    4    T384      19.0  1.0   19.0   19.0
# ...     ...       ...  ...     ...       ...  ...    ...    ...
# 26980    M3       N10   31   T5999      10.0  1.0   10.0   10.0
# 26981    M3       N10   31   T6007      88.0  1.0   10.0   10.0
# 26982    M3       N10   31   T6007      88.0  2.0   20.0   10.0
# 26983    M3       N10   31   T6007      88.0  1.0   58.0   58.0
# 26984    M3       N10   31   T6013      15.0  1.0   15.0   15.0
#
#                               GRP                     SGRP  \
# 0            BUTTER MARGR  (4/94)                   BUTTER
# 1         CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# ...

# %%
df.shape
# Out:
# (26985, 14)

# %%
df.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0    M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1    M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2    M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3    M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4    M1        N1    4    T384      19.0  1.0   19.0   19.0
#
#                        GRP                     SGRP                    SSGRP  \
# 0     BUTTER MARGR  (4/94)                   BUTTER                   SALTED
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2                CHOCOLATE         CHOCOLATE PANNED         CHOCOLATE PANNED
# 3             PACKAGED TEA               MAIN PACKS               MAIN PACKS
# 4         ALL IODISED SALT            POWDERED SALT            POWDERED SALT
#
#                       CMP           MBRD                 BRD
# 0               G C M M F           AMUL                AMUL
# ...

# %%
df.dtypes
# Out:
# MONTH         object
# STORECODE     object
# DAY            int64
# BILL_ID       object
# BILL_AMT     float64
# QTY          float64
# VALUE        float64
# PRICE        float64
# GRP           object
# SGRP          object
# SSGRP         object
# CMP           object
# MBRD          object
# BRD           object
# dtype: object

# %%
df.describe()
# Out:
#                 DAY      BILL_AMT           QTY         VALUE         PRICE
# count  26985.000000  26970.000000  26967.000000  26962.000000  26971.000000
# mean      15.167019    278.838089      4.121741     67.829291     52.826722
# std        8.956057    541.529958     95.729206    118.039071     85.004845
# min        1.000000      0.000000      0.500000      0.000000      0.000000
# 25%        7.000000     40.000000      1.000000     10.000000     10.000000
# 50%       14.000000    111.000000      1.000000     30.000000     22.000000
# 75%       23.000000    280.000000      2.000000     80.000000     65.000000
# max       31.000000   7292.000000  12000.000000   3150.000000   3150.000000

# %%
df.isnull()
# Out:
#        MONTH  STORECODE    DAY  BILL_ID  BILL_AMT    QTY  VALUE  PRICE    GRP  \
# 0      False      False  False    False     False  False  False  False  False
# 1      False      False  False    False     False  False  False  False  False
# 2      False      False  False    False     False  False  False  False  False
# 3      False      False  False    False     False  False  False  False  False
# 4      False      False  False    False     False  False  False  False  False
# ...      ...        ...    ...      ...       ...    ...    ...    ...    ...
# 26980  False      False  False    False     False  False  False  False  False
# 26981  False      False  False    False     False  False  False  False  False
# 26982  False      False  False    False     False  False  False  False  False
# 26983  False      False  False    False     False  False  False  False  False
# 26984  False      False  False    False     False  False  False  False  False
#
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
##df.groupby(["STORECODE"]).sum().sort_values("MONTH", ascending= False )
df.groupby('MONTH').STORECODE.sum().sort_index()
# Out:
# MONTH
# M1    N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1...
# M2    N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1...
# M3    N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1N1...
# Name: STORECODE, dtype: object

# %%
df.groupby(['MONTH','BILL_AMT']).sum()
##df[['MONTH','BILL_AMT']].sum(axis=1)
##df.groupby(['MONTH','BILL_AMT']).apply(lambda x : x.astype(int64).sum())
# Out:
#                 DAY     QTY    VALUE    PRICE
# MONTH BILL_AMT
# M1    0.00       24     1.0     0.00     0.00
#       1.00       50     3.0     3.00     3.00
#       1.58        8     2.0     1.58     0.79
#       2.00      191    14.0    22.00    19.00
#       3.00       15     1.0     3.00     3.00
# ...             ...     ...      ...      ...
# M3    2346.00    70    27.0  2346.00  1725.75
#       2375.00    24    12.0  2375.00  1379.00
#       3438.00    66  3018.0  3438.00  1324.33
#       6040.00    95    27.0  6040.00  1130.00
#       7292.00    36    33.0  7292.00  1626.00
#
# [2417 rows x 4 columns]

# %%
## MONTH WISE STORECODE. BILL_AMT, QTY 
##df.groupby(['MONTH', 'STORECODE'])['BILL_AMT','QTY'].apply(lambda x : x.astype(int).count())
df_new = df.groupby(['MONTH', 'STORECODE']).sum()[['BILL_AMT','QTY']].sort_values(['MONTH'], ascending= True )
df_new
# Out:
#                   BILL_AMT      QTY
# MONTH STORECODE
# M1    N1         311459.59   3980.0
#       N10         99128.00    497.0
#       N2         235704.00   2638.0
#       N3         222674.50   1231.0
#       N4         274727.45   2237.0
#       N5         101554.00   1077.0
#       N6          18047.00    111.0
#       N7         286420.54   8866.0
#       N8         140319.87    619.0
#       N9         610348.02   1249.0
# M2    N9         878590.29   1199.0
#       N8         116769.26    834.0
#       N7         477371.73   4826.0
#       N6          72427.00    461.0
#       N5         286437.00   2945.0
#       N4         255547.36   2349.0
#       N3         183363.87   1055.0
#       N2         275495.00   8040.0
#       N10        280629.00   1917.0
#       N1          81601.34  12631.0
# M3    N1         232221.85  24293.0
#       N10        170350.00   1174.0
#       N2         282126.00  13102.0
#       N3          88498.00    591.0
# ...

# %%
df_new.columns
# Out:
# Index(['BILL_AMT', 'QTY'], dtype='object')

# %%
df_new2 = df.groupby(['MONTH', 'STORECODE']).sum()[['BILL_AMT','QTY','VALUE']].sort_values(['MONTH'], ascending= True )
##df_new2 = df_new.sum('VALUE')
df_new2
# Out:
#                   BILL_AMT      QTY      VALUE
# MONTH STORECODE
# M1    N1         311459.59   3980.0   71146.93
#       N10         99128.00    497.0   21437.00
#       N2         235704.00   2638.0   76258.00
#       N3         222674.50   1231.0   55333.50
#       N4         274727.45   2237.0   60138.18
#       N5         101554.00   1077.0   36592.00
#       N6          18047.00    111.0    7062.00
#       N7         286420.54   8866.0   85533.47
#       N8         140319.87    619.0   25565.83
#       N9         610348.02   1249.0  113046.01
# M2    N9         878590.29   1199.0  121447.02
#       N8         116769.26    834.0   34008.02
#       N7         477371.73   4826.0  124959.94
#       N6          72427.00    461.0   23967.00
#       N5         286437.00   2945.0   96550.00
#       N4         255547.36   2349.0   61196.76
#       N3         183363.87   1055.0   47424.29
#       N2         275495.00   8040.0   62954.00
#       N10        280629.00   1917.0   74383.00
# ...

# %%
## MONTH WISE HIGHEST SOLD OF STORES
ds = df_new.sort_values(['MONTH','BILL_AMT'], ascending = False )
ds
# Out:
#                   BILL_AMT      QTY
# MONTH STORECODE
# M3    N4         341940.89   3322.0
#       N5         307764.00   3120.0
#       N2         282126.00  13102.0
#       N6         276056.00   1362.0
#       N7         273029.47   4205.0
#       N8         235728.22   1055.0
#       N1         232221.85  24293.0
#       N10        170350.00   1174.0
#       N9         103934.00    165.0
#       N3          88498.00    591.0
# M2    N9         878590.29   1199.0
#       N7         477371.73   4826.0
#       N5         286437.00   2945.0
#       N10        280629.00   1917.0
#       N2         275495.00   8040.0
#       N4         255547.36   2349.0
#       N3         183363.87   1055.0
#       N8         116769.26    834.0
#       N1          81601.34  12631.0
#       N6          72427.00    461.0
# M1    N9         610348.02   1249.0
#       N1         311459.59   3980.0
#       N7         286420.54   8866.0
#       N4         274727.45   2237.0
# ...

# %%
hsale = df['BILL_AMT'].head()
hsale
# Out:
# 0    225.0
# 1     95.0
# 2     10.0
# 3    108.0
# 4     19.0
# Name: BILL_AMT, dtype: float64

# %%
ds_new.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d03dd3420620> in <module>
# ----> 1 ds_new.head()
#
# NameError: name 'ds_new' is not defined

# %%
ds.tail()
# Out:
#                   BILL_AMT     QTY
# MONTH STORECODE
# M1    N3         222674.50  1231.0
#       N8         140319.87   619.0
#       N5         101554.00  1077.0
#       N10         99128.00   497.0
#       N6          18047.00   111.0

# %%
Sup = df_new.sort_values('BILL_AMT', ascending = False)
Sup
# Out:
#                   BILL_AMT      QTY
# MONTH STORECODE
# M2    N9         878590.29   1199.0
# M1    N9         610348.02   1249.0
# M2    N7         477371.73   4826.0
# M3    N4         341940.89   3322.0
# M1    N1         311459.59   3980.0
# M3    N5         307764.00   3120.0
# M2    N5         286437.00   2945.0
# M1    N7         286420.54   8866.0
# M3    N2         282126.00  13102.0
# M2    N10        280629.00   1917.0
# M3    N6         276056.00   1362.0
# M2    N2         275495.00   8040.0
# M1    N4         274727.45   2237.0
# M3    N7         273029.47   4205.0
# M2    N4         255547.36   2349.0
# M3    N8         235728.22   1055.0
# M1    N2         235704.00   2638.0
# M3    N1         232221.85  24293.0
# M1    N3         222674.50   1231.0
# M2    N3         183363.87   1055.0
# M3    N10        170350.00   1174.0
# M1    N8         140319.87    619.0
# M2    N8         116769.26    834.0
# M3    N9         103934.00    165.0
# ...

# %%
##Month & Store code wise highest bill amount & QTY
Sup.head()
# Out:
#                   BILL_AMT     QTY
# MONTH STORECODE
# M2    N9         878590.29  1199.0
# M1    N9         610348.02  1249.0
# M2    N7         477371.73  4826.0
# M3    N4         341940.89  3322.0
# M1    N1         311459.59  3980.0

# %%
Sup.tail()
# Out:
#                  BILL_AMT      QTY
# MONTH STORECODE
# M1    N10        99128.00    497.0
# M3    N3         88498.00    591.0
# M2    N1         81601.34  12631.0
#       N6         72427.00    461.0
# M1    N6         18047.00    111.0

# %%
##Store wise total bill amount of 3 months
df_new.groupby('STORECODE').BILL_AMT.sum().sort_index()
# Out:
# STORECODE
# N1      625282.78
# N10     550107.00
# N2      793325.00
# N3      494536.37
# N4      872215.70
# N5      695755.00
# N6      366530.00
# N7     1036821.74
# N8      492817.35
# N9     1592872.31
# Name: BILL_AMT, dtype: float64

# %%
##barplot of bill amount for finding outlayers
sns.boxplot(x =df_new2['BILL_AMT'])

# %%
##sns.barplot(x= 'MONTH', y= 'BILL_AMT', data=df_new2)
##data1 = df_new2.copy()
##data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('M1', 'N1') to ('M3', 'N9')
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BILL_AMT  30 non-null     float64
#  1   QTY       30 non-null     float64
#  2   VALUE     30 non-null     float64
# dtypes: float64(3)
# memory usage: 996.0+ bytes

# %%
#df_new2.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('M1', 'N1') to ('M3', 'N9')
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BILL_AMT  30 non-null     float64
#  1   QTY       30 non-null     float64
#  2   VALUE     30 non-null     float64
# dtypes: float64(3)
# memory usage: 996.0+ bytes

# %%
df2 =  df.copy()

# %%
df2.columns
# Out:
# Index(['MONTH', 'STORECODE', 'DAY', 'BILL_ID', 'BILL_AMT', 'QTY', 'VALUE',
#        'PRICE', 'GRP', 'SGRP', 'SSGRP', 'CMP', 'MBRD', 'BRD'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      26985 non-null  object
#  1   STORECODE  26985 non-null  object
#  2   DAY        26985 non-null  int64
#  3   BILL_ID    26975 non-null  object
#  4   BILL_AMT   26970 non-null  float64
#  5   QTY        26967 non-null  float64
#  6   VALUE      26962 non-null  float64
#  7   PRICE      26971 non-null  float64
#  8   GRP        26981 non-null  object
#  9   SGRP       26980 non-null  object
#  10  SSGRP      26980 non-null  object
#  11  CMP        26985 non-null  object
#  12  MBRD       26985 non-null  object
#  13  BRD        26985 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
#df2[['MONTH','STORECODE']] = df2[['MONTH','STORECODE']].astype('category')

# %%
#df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      26985 non-null  category
#  1   STORECODE  26985 non-null  category
#  2   DAY        26985 non-null  int64
#  3   BILL_ID    26975 non-null  object
#  4   BILL_AMT   26970 non-null  float64
#  5   QTY        26967 non-null  float64
#  6   VALUE      26962 non-null  float64
#  7   PRICE      26971 non-null  float64
#  8   GRP        26981 non-null  object
#  9   SGRP       26980 non-null  object
#  10  SSGRP      26980 non-null  object
#  11  CMP        26985 non-null  object
#  12  MBRD       26985 non-null  object
#  13  BRD        26985 non-null  object
# dtypes: category(2), float64(4), int64(1), object(7)
# memory usage: 2.5+ MB

# %%
df3 = df2.groupby(['MONTH','STORECODE'])[['BILL_AMT','QTY','VALUE','PRICE']].sum()

# %%
df3
# Out:
#                   BILL_AMT      QTY      VALUE      PRICE
# MONTH STORECODE
# M1    N1         311459.59   3980.0   71146.93   59987.70
#       N10         99128.00    497.0   21437.00   18489.00
#       N2         235704.00   2638.0   76258.00   46521.27
#       N3         222674.50   1231.0   55333.50   44164.50
#       N4         274727.45   2237.0   60138.18   45056.73
#       N5         101554.00   1077.0   36592.00   30885.00
#       N6          18047.00    111.0    7062.00    5930.00
#       N7         286420.54   8866.0   85533.47   70699.39
#       N8         140319.87    619.0   25565.83   17397.81
#       N9         610348.02   1249.0  113046.01   80795.67
# M2    N1          81601.34  12631.0   20960.64   16999.63
#       N10        280629.00   1917.0   74383.00   58024.00
#       N2         275495.00   8040.0   62954.00   40341.76
#       N3         183363.87   1055.0   47424.29   38483.29
#       N4         255547.36   2349.0   61196.76   44710.97
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30 entries, ('M1', 'N1') to ('M3', 'N9')
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BILL_AMT  30 non-null     float64
#  1   QTY       30 non-null     float64
#  2   VALUE     30 non-null     float64
#  3   PRICE     30 non-null     float64
# dtypes: float64(4)
# memory usage: 1.6 KB

# %%
sns.barplot(x= 'MONTH', y= 'BILL_AMT', data=df2)

# %%
sns.barplot(x = 'STORECODE', y = 'BILL_AMT',hue = 'MONTH',data = df2)

# %%
sns.countplot(x ='STORECODE', data = df2)

# %%
sns.boxplot(x =df2['BILL_AMT'])

# %%
import matplotlib.pyplot as plt   ### Basic 
plt.figure(figsize = (12,10))
sns.boxplot(x = 'MONTH',y = 'BILL_AMT',data = df2, hue = 'STORECODE')

# %%
corr = df2.corr()
corr
# Out:
#                DAY  BILL_AMT       QTY     VALUE     PRICE
# DAY       1.000000 -0.048912  0.008296 -0.027478 -0.021447
# BILL_AMT -0.048912  1.000000  0.027435  0.460705  0.350345
# QTY       0.008296  0.027435  1.000000  0.067210 -0.018400
# VALUE    -0.027478  0.460705  0.067210  1.000000  0.791860
# PRICE    -0.021447  0.350345 -0.018400  0.791860  1.000000

# %%
sns.regplot(x = 'VALUE',y = 'BILL_AMT',data = df2)

# %%
sns.pairplot(df2)
